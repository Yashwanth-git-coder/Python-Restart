# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")

print(f"Hello, {first_name} {last_name}!")
# Out:
# Hello, Yashwanth QuestIn!

# %%
age = 23
if age > 18:
    print("You are an adult.")
else:
    print("You are a minor.")
# Out:
# You are an adult.
