# %%
#Declaring and Assigning Variables

age = 32
height = 5.9
name = "Yashwanth"
is_student = False

print("Age:", age)
print("Height:", height)
print("Name:", name)
print("Is Student:", is_student)
# Out:
# Age: 32
# Height: 5.9
# Name: Yashwanth
# Is Student: False

# %%
print("Data Types:")
# Out:
# Data Types:
